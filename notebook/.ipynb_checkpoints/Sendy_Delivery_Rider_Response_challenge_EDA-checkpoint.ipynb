# %% [markdown]
# ## PART B: EXPLORATORY DATA ANALYSIS

# %%
# %import libraries
import pandas as pd
import sweetviz as sv
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
# %loading datasets
train = pd.read_csv("../data/Train.csv")
riders = pd.read_csv("../data/Riders.csv")

# %%
# %inspect the datasets
train.shape , riders.shape
# Out:
# ((179867, 21), (2632, 4))

# %% [markdown]
# ### Variable definitions
#
# **Dispatch Data:**
#
# - **ID** - Unique ID for each order request
# - **order_id** – Unique number identifying the order
# - **client_id** - Unique number identifying the customer on a platform
# - **client_type** - Specifies the customer type (Business or Personal)
# - **rider_id** - Unique number to uniquely identify the rider
# - **rider_license_status** - Identifies riders who have a license to access restricted areas i.e. 0 (Cannot access a - - restricted area) and 1 (Can access a restricted area)
# - **rider_carrier_type** - Identifies the box option that a rider currently has i.e. 0 (No Box option) and 1 (Box option)
# - **rider_amount** - The earnings a partner would earn if they successfully complete an order.
# - **order_license_status** - Identifies orders that require a pick-up or drop-off in a restricted area i.e. 0 (Restricted area) and 1 (Non-Restricted area)
# - **order_carrier_type** - Identifies the box option the customer specified while placing their orders i.e. 0 (No box option), 1 (Box option), 2 (Any option)
# - **vendor_type** – For this competition limited to bikes. However, in practice, Sendy’s service extends to Vans and Trucks.
# - **Pickup Latitude and Longitude (pickup_lat and pickup_long)** - Latitude and longitude of pick up location
# - **Destination Latitude and Longitude (drop_off_lat and drop_off_long)** - Latitude and longitude of delivery location
# - **Rider Latitude and Longitude (rider_lat and rider_long)** - Latitude and longitude of the Rider at the time of dispatch.
# - **target** - The reaction of a rider in regards to a particular dispatch. Did a rider ignore (0), decline (1) or accept (2) a dispatch?
#
# **Dispatch times:**
#
# - **dispatch_day** - Day of Month i.e. 1-31
# - **dispatch_day_of_week** - Weekday (Monday = 1)
# - **dispatch_time** - Time of day the dispatch was sent out to the riders

# %%
# %preview the train data
train.head()
# Out:
#               ID  order_id  dispatch_day  dispatch_day_of_week dispatch_time  \
# 0  ID_SCUW21PVAU      4435            27                     6      09:02:54
# 1  ID_2HA7X30JMN     32711            30                     7      13:01:37
# 2  ID_IAJWDTBY6M      8712            14                     2      10:01:00
# 3  ID_LKSVPNYMTR     44869            22                     3      14:11:16
# 4  ID_O7N8Y918YH     57590            27                     5      16:11:38
#
#    client_id client_type  order_license_status  order_carrier_type  \
# 0     593630    Business                     0                   2
# 1     837729    Personal                     0                   1
# 2     695129    Personal                     0                   2
# 3    1504660    Personal                     0                   2
# 4      36869    Business                     0                   2
#
#   vendor_type  ...  rider_license_status  rider_carrier_type  rider_amount  \
# ...

# %%
# %preview the riders data
riders.head()
# Out:
#    Rider ID  Active Rider Age  Average Partner Rating  Number of Ratings
# 0     16261               308                   21.05                321
# 1      8832               224                   10.00                 27
# 2     53866               238                   17.76                 25
# 3     46368               343                   24.56                320
# 4     45609               399                   14.97                214

# %%
# %checking for missing values
train.isnull().sum().any()
# Out:
# False

# %%
# %checking for missing values
riders.isnull().sum().any()
# Out:
# False

# %%
# %data informations
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179867 entries, 0 to 179866
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    179867 non-null  object
#  1   order_id              179867 non-null  int64
#  2   dispatch_day          179867 non-null  int64
#  3   dispatch_day_of_week  179867 non-null  int64
#  4   dispatch_time         179867 non-null  object
#  5   client_id             179867 non-null  int64
#  6   client_type           179867 non-null  object
#  7   order_license_status  179867 non-null  int64
#  8   order_carrier_type    179867 non-null  int64
#  9   vendor_type           179867 non-null  object
#  10  rider_id              179867 non-null  int64
#  11  rider_license_status  179867 non-null  int64
#  12  rider_carrier_type    179867 non-null  int64
#  13  rider_amount          179867 non-null  int64
# ...

# %%
# %inspect statistical relationship for numeric features
train.describe().T
# Out:
#                          count           mean            std          min  \
# order_id              179867.0   32639.833149   18227.428596   100.000000
# dispatch_day          179867.0      16.604903       8.528368     1.000000
# dispatch_day_of_week  179867.0       4.185198       1.683574     1.000000
# client_id             179867.0  465410.752400  663423.434197   261.000000
# order_license_status  179867.0       0.239555       0.426813     0.000000
# order_carrier_type    179867.0       1.619007       0.536552     0.000000
# rider_id              179867.0   70389.969944   33981.806096  1817.000000
# rider_license_status  179867.0       0.589936       0.491846     0.000000
# rider_carrier_type    179867.0       0.868731       0.337695     0.000000
# rider_amount          179867.0     517.544185     157.385430   200.000000
# rider_lat             179867.0     -42.817124       0.106837   -45.736540
# rider_long            179867.0     -17.286813       0.100707   -20.079067
# ...

# %% [markdown]
# #### OBSERVATION
#
# - average of orders across the platform occurs from Thursday to Friday
# - the highest paying oders are of value 2190 , while least paying is 200
# - the average of oders across the platform has value of 518
# -

# %%
riders.describe().T
# Out:
#                          count          mean           std    min       25%  \
# Rider ID                2632.0  73738.323328  28424.105449  805.0  54803.25
# Active Rider Age        2632.0     44.490881     63.154074    0.0      3.00
# Average Partner Rating  2632.0     17.530015      5.185067    1.0     14.44
# Number of Ratings       2632.0    133.109422    118.880935    0.0     33.00
#
#                               50%         75%        max
# Rider ID                74025.500  98376.7500  123694.00
# Active Rider Age           14.000     62.0000     399.00
# Average Partner Rating     18.535     21.6625      24.99
# Number of Ratings         105.500    205.0000     637.00

# %% [markdown]
# ### PERFORM INITIAL SWEETVIZ ANALYSIS TO GET A FEEL OF THE DATA

# %%
# %perform EDA analysis
train_report = sv.analyze(train)
train_report.show_notebook()
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# ### ANALYSIS
#
# #### OBSERVATION
#
# - No any missing entry and No dublicates entries
# - 8 of features are categorical and 11 are numerical features
# - Labels are not well balanced, most of riders ignored and rejected the orders(80%), Only few of them tend to accept orders across the platform(20%).
# - The data collected based on one vendor type which is `Bike`.
# - Most of riders(rider_lisence_status) can access restricted areas and few of them can't
# - Most of riders has carrier type of box and few of them has other type of carriers
# - The platform has two types of clients where Business type dominated across the platform(81%) and few are Personal clients.
# - Most of orders placed across the platform require a pick-up or drop-off in a restricted area so it need a rider to have licence.
# - Most of customers place order for any carrier option, 30% of orders require rider to have box carrier and 3% require a rider to have no box carrier
# - Friday and Saturday are days that lead on the number of orders
# - Also more order on the end  days of the month(27,28,29,30 and 31)

# %%
# %perform EDA analysis
r_report = sv.analyze(riders)
r_report.show_notebook()
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# ### ANALYSIS
#
# #### OBSERVATIONS
#
# - Most of rider ratings are below 200 across the platform.
# - Most of riders are aged below 100

# %% [markdown]
# ### COMBINING THE DATASETS

# %%
df = train.merge(riders, how = 'left',left_on='rider_id', right_on='Rider ID' )
df.head()
# Out:
#               ID  order_id  dispatch_day  dispatch_day_of_week dispatch_time  \
# 0  ID_SCUW21PVAU      4435            27                     6      09:02:54
# 1  ID_2HA7X30JMN     32711            30                     7      13:01:37
# 2  ID_IAJWDTBY6M      8712            14                     2      10:01:00
# 3  ID_LKSVPNYMTR     44869            22                     3      14:11:16
# 4  ID_O7N8Y918YH     57590            27                     5      16:11:38
#
#    client_id client_type  order_license_status  order_carrier_type  \
# 0     593630    Business                     0                   2
# 1     837729    Personal                     0                   1
# 2     695129    Personal                     0                   2
# 3    1504660    Personal                     0                   2
# 4      36869    Business                     0                   2
#
#   vendor_type  ...  rider_long  pickup_lat  pickup_long  drop_off_lat  \
# ...

# %%
df.isnull().sum().any()
# Out:
# False

# %% [markdown]
# ### BIVARIATE & MULTIVARIATE ANALYSIS
#
# We have gone through single variable analysis, it's time to observe the relationship between more than variables.
#
# - ##### Bivariate Analysis on Categorical Variables
#
#
# - ##### Bivariate Analysis on Continuous Variables
#
#
# #### PART A: CATEGORICAL VARIABLES

# %%
# Let's visualize the distribution between type of customers and the labels
plt.figure(figsize=(15,7))
sns.countplot(x = 'client_type', hue = 'target', data = df)
plt.title('CUSTOMER TYPE & LABELS')
plt.show()

# %% [markdown]
# As most of orders are from business clients but we can see that most of them are reacted negatively we can keep investigation to find out why?

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'client_type', hue = 'order_license_status', data = df)
plt.title('CUSTOMER TYPE & ORDER LICENSE STATUS')
plt.show()

# %% [markdown]
# Most of business orders are from restricted area which require a rider to have license, let's find out if we can confirm somenthing here by looking on the relationship between customer types and rider license status

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'client_type', hue = 'rider_license_status', data = df)
plt.title('CUSTOMER TYPE & RIDER LICENSE STATUS')
plt.show()

# %% [markdown]
# Most of business orders goes to rider with access to restricted area, same to personal orders.We can't conclude only by looking on this we should look on other factors too.

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'order_license_status', hue = 'target', data = df)
plt.title('ORDER LICENSE STATUS & LABELS')
plt.show()

# %% [markdown]
# High rate of orders which cancelled require license to pick or to drop

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'rider_license_status', hue = 'target', data = df)
plt.title('RIDER LICENSE STATUS & LABELS')
plt.show()

# %% [markdown]
# The number of oders cancled by Riders who can access restricted areas is high compared to those who can't
#
# - May be on restricted area there is complication on accessing

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'rider_license_status', hue = 'rider_carrier_type', data = df)
plt.title('RIDER LICENSE STATUS & RIDER CARRIER TYPE')
plt.show()

# %% [markdown]
# Most of riders who can access restricted areas has bike with box carriers

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'rider_carrier_type', hue = 'target', data = df)
plt.title('RIDER CARRIER TYPE & LABELS')
plt.show()

# %% [markdown]
# Riders who have bikes with box carrier are the one leading to cancel the orders

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'client_type', hue = 'rider_carrier_type', data = df)
plt.title('RIDER CARRIER TYPE & CLIENT TYPE')
plt.show()

# %% [markdown]
# Most of riders received business orders they have bike with box carrier

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'client_type', hue = 'order_carrier_type', data = df)
plt.title('ORDER CARRIER TYPE & CLIENT TYPE')
plt.show()

# %% [markdown]
# Around 60,000 of business orders they come from customers who restrict for riders with box carriers, This confirms that box carrier demand is not the case

# %% [markdown]
# #### PART B: CONTINUOUS & CATEGORICAL VARIABLES

# %%
df['dispatch_day'].value_counts().plot(kind='bar',figsize=[15,7])
plt.show()

# %% [markdown]
# Days at the end of the month are more busy compared to starting day of month

# %%
df['dispatch_day_of_week'].value_counts().plot(kind='bar',figsize=[15,7])
plt.show()

# %% [markdown]
# Monday and sunday is less busy compared to other days, and saturday is a busy day compared to all week days

# %%
target_rider_amount = sns.catplot(x="target", y="rider_amount",data=df, aspect=1.5, height=7, ci=80.0)

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'dispatch_day', hue = 'target', data = df)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x = 'dispatch_day_of_week', hue = 'target', data = df)
plt.show()

# %% [markdown]
# - The trend of negative reaction from rider seems to be the same depending on the number of order on the specific day.
# - Each single day more orders are ignored and canceled rather than accepted

# %% [markdown]
# #### PART C: HEAT MAP TO UNDERSTAND THE CORRELATIONS

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df.corr(), annot=True ,cmap="magma")
plt.show()

# %%
# %Let's save the dataset for further engineering of features
df.to_csv("../data/combined_data.csv",index=False)
